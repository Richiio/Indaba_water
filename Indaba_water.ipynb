# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import math

# %%
build_data=pd.read_csv('/content/Train.csv')
test_data=pd.read_csv('/content/Test.csv')
ss = pd.read_csv('/content/SampleSubmission.csv')

# %%
build_data.head()
# Out:
#        region_area_        ph    Hardness        Solids  Chloramines  \
# 0     region_area_1  3.716080  180.196811  18630.362669     6.330435
# 1   region_area_100  4.270716  217.611599  24405.555346     7.086700
# 2  region_area_1000  6.648849  232.462013  30733.808648     5.656462
# 3  region_area_1001       NaN  261.753637  21174.713291     7.314074
# 4  region_area_1002  9.323584  263.484560  15751.480111     5.196259
#
#       Sulfate  Conductivity  Organic_carbon  Trihalomethanes  Turbidity  \
# 0         NaN    602.990359       15.285013        56.444076   4.500656
# 1  297.951852    359.623910       13.583526        54.589840   3.763906
# 2  344.670335    267.809179       17.863444        35.411181   4.827527
# 3         NaN    582.848407       15.215849        90.367455   4.217553
# 4  297.593625    409.878704       10.727265        74.669285   3.006650
#
#    Potability
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0

# %%
build_data.describe()
# Out:
#                 ph     Hardness        Solids  Chloramines      Sulfate  \
# count  1924.000000  2260.000000   2260.000000  2260.000000  1713.000000
# mean      7.083561   247.000935  22100.926521     6.802715   334.601013
# std       1.596243    33.162065   8829.474740     1.592352    42.216115
# min       0.000000   124.266124    321.247422     0.047189   129.745113
# 25%       6.114364   226.799112  15761.393491     5.800652   307.637713
# 50%       7.060886   247.379235  21149.453853     6.828266   333.943304
# 75%       8.045673   267.798367  27347.271380     7.802569   361.159118
# max      13.541240   373.897891  61227.500818    12.822189   481.775755
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity   Potability
# count   2260.000000     2260.000000      2149.000000  2260.000000  2260.000000
# mean     436.572437       14.359075        66.440129     3.969176     0.388496
# std       80.645313        3.298100        16.321315     0.777228     0.487516
# min      211.724737        4.476899         0.853000     1.450000     0.000000
# 25%      376.894507       12.154291        55.918503     3.444178     0.000000
# 50%      432.813965       14.325645        66.727984     3.962502     0.000000
# 75%      492.076858       16.625857        77.488813     4.502519     1.000000
# max      718.331364       28.405000       124.115000     6.739000     1.000000

# %%
build_data['Potability'].value_counts()
# Out:
# 0    1382
# 1     878
# Name: Potability, dtype: int64

# %%
build_data.groupby('Potability').median()
# Out:
#                   ph    Hardness        Solids  Chloramines     Sulfate  \
# Potability
# 0           7.078659  247.444825  21032.975504     6.780508  334.244316
# 1           7.040395  247.357106  21370.885301     6.959241  332.841184
#
#             Conductivity  Organic_carbon  Trihalomethanes  Turbidity
# Potability
# 0             432.813965       14.434839        66.816621   3.972916
# 1             433.073967       14.257659        66.536231   3.958576

# %%
for i in build_data:
  if i != ('ph') and i != ('region_area_'):
    plt.figure(figsize=(6,6))
    sns.scatterplot(x=i, y='ph', hue='Potability', data=build_data)
    plt.title(f'ph vs {i}')
    plt.show()

# %%
for i in build_data:
  if i != ('Potability') and i != ('region_area_'):
    plt.figure(figsize=(6,6))
    sns.histplot(data=build_data, x=i)
    plt.title(f'{i}')
    plt.show()

# %% [markdown]
# all columns shape display gaussian distibution

# %%
build_data.isna().sum()
# Out:
# region_area_         0
# ph                 336
# Hardness             0
# Solids               0
# Chloramines          0
# Sulfate            547
# Conductivity         0
# Organic_carbon       0
# Trihalomethanes    111
# Turbidity            0
# Potability           0
# dtype: int64

# %%
build_data[build_data['ph']<7][:10]
# Out:
#         region_area_        ph    Hardness        Solids  Chloramines  \
# 0      region_area_1  3.716080  180.196811  18630.362669     6.330435
# 1    region_area_100  4.270716  217.611599  24405.555346     7.086700
# 2   region_area_1000  6.648849  232.462013  30733.808648     5.656462
# 5   region_area_1003  4.581969  236.871806  33897.373012     6.053592
# 7   region_area_1005  6.168839  289.074938  24827.821451     7.415200
# 12  region_area_1014  5.487876  229.980874  20162.323428     4.906620
# 16  region_area_1018  6.013161  269.617147  21574.052382     8.991041
# 18  region_area_1020  5.218990  215.564882  27008.191716     6.287706
# 22  region_area_1024  6.729580  292.938037  17975.858038     9.503841
# 24  region_area_1028  6.209697  220.092395  22611.073524     4.570603
#
#        Sulfate  Conductivity  Organic_carbon  Trihalomethanes  Turbidity  \
# 0          NaN    602.990359       15.285013        56.444076   4.500656
# 1   297.951852    359.623910       13.583526        54.589840   3.763906
# 2   344.670335    267.809179       17.863444        35.411181   4.827527
# 5   317.297905    416.487378       19.804848        62.438303   4.500208
# 7   270.235286    492.778327       22.196990        79.284281   4.435760
# 12  306.009255    520.714385       12.693475        58.976558   4.223576
# 16  321.913426    454.381635       14.849347        62.558239   3.455623
# 18         NaN    432.328802       14.175879        74.035320   4.383943
# 22  322.980215    450.964435       13.676223        62.294477   4.003458
# 24  328.125052    559.381728       17.120118        51.620508   3.893767
#
#     Potability
# 0            0
# 1            0
# 2            0
# 5            0
# 7            0
# 12           0
# 16           0
# 18           0
# 22           0
# 24           0

# %%
build_data[build_data['ph']>7][:10]
# Out:
#         region_area_         ph    Hardness        Solids  Chloramines  \
# 4   region_area_1002   9.323584  263.484560  15751.480111     5.196259
# 6   region_area_1004   7.884842  280.016551  21734.132854     7.598271
# 9   region_area_1008   8.693104  235.546700  13284.082864     6.217004
# 11   region_area_101   7.348845  274.038830  11519.351338     8.584748
# 14  region_area_1016   8.315959  272.044113  16123.609261     9.170991
# 15  region_area_1017   8.551078  267.189823  28909.595095     6.631972
# 17   region_area_102   8.526170  226.386727  11837.428170     7.178898
# 20  region_area_1022   7.458708  258.560464  10513.601592     8.615822
# 21  region_area_1023  11.027880  279.096688  13124.410447     7.211833
# 23  region_area_1026   7.159398  222.589996  28955.105823     5.512280
#
#        Sulfate  Conductivity  Organic_carbon  Trihalomethanes  Turbidity  \
# 4   297.593625    409.878704       10.727265        74.669285   3.006650
# 6   315.935097    378.875894       11.740399        49.919322   4.631641
# 9   349.299905    571.070910       14.083348        71.848845   2.898223
# 11         NaN    504.263434       18.250374        73.830522   4.880875
# 14  348.922444    511.778983       22.264747        75.479974   2.760213
# 15  295.968820    521.000001       16.307371        79.974323   4.046380
# 17  309.143629    484.345482       21.950916        52.487201   5.083014
# 20         NaN    452.473143       18.830302        44.013088   2.938082
# 21  320.099153    386.336918        8.138859        48.644038   4.178898
# 23  358.073872    540.631411       18.222042        79.209440   3.254926
#
#     Potability
# 4            0
# 6            0
# 9            0
# 11           0
# 14           0
# 15           0
# 17           0
# 20           0
# 21           0
# 23           0

# %%
null_data = build_data[build_data[['ph', 'Solids']].isnull().any(axis=1)]

# %%
null_data.shape
# Out:
# (336, 11)

# %%
lis3=[]
for i in build_data:
    lis3.append(build_data[str(i)].nunique())

cardinal=pd.DataFrame(lis3,build_data.columns).reset_index()
cardinal=cardinal.rename(columns={'index':'Features',0:'cardinality'})

# %%
cardinal
# Out:
#            Features  cardinality
# 0      region_area_         2260
# 1                ph         1924
# 2          Hardness         2260
# 3            Solids         2260
# 4       Chloramines         2260
# 5           Sulfate         1713
# 6      Conductivity         2260
# 7    Organic_carbon         2260
# 8   Trihalomethanes         2149
# 9         Turbidity         2260
# 10       Potability            2

# %%
# join train and test together
ntrain = build_data.shape[0]
ntest = test_data.shape[0]

all_data = pd.concat((build_data, test_data)).reset_index(drop=True)
print("all_data size is : {}".format(all_data.shape))
# Out:
# all_data size is : (3276, 11)

# %%
all_data['Sulph'] = all_data['Sulfate']/all_data['ph']
all_data['ocph'] = all_data['Organic_carbon']/all_data['ph']

# %%
for col in all_data:
  if col != 'Potability':
    all_data[col].fillna(-99, inplace = True)

# %%
def ph(x):
    if 0 < x <= 3:
        return 1
    elif x == -99:
      return -99
    elif 3 < x <= 5:
        return 2
    elif 5 < x <= 7.5:
        return 3
    elif 7.5 < x <= 9:
        return 4
    elif 9 < x <= 12:
        return 5
    else:
        return 6

# %%
all_data['ph_range'] = all_data['ph'].apply(ph)
all_data['H30+'] = np.where(all_data['ph'] == -99, -99, np.power(10,-1*all_data['ph']) )

# %%
chl_ph = []
for a,b in zip(all_data['ph'], all_data['Chloramines']):
  if (a <7.5) and (b >6.77):
    chl_ph.append(1)
  elif (a < 7.5) and (b < 6.77):
    chl_ph.append(2)
  elif (a > 7.5) and (b > 6.77):
    chl_ph.append(3)
  elif (a > 7.5) and (b < 6.77):
    chl_ph.append(4)
  else:
    chl_ph.append(5)

# %%
all_data['chl_ph'] = chl_ph

# %%
hard_ph = []
for a,b in zip(all_data['ph'], all_data['Hardness']):
  if (a > 7) and (b >250):
    hard_ph.append(1)
  elif (a < 7) and (b < 250):
    hard_ph.append(2)
  elif (a < 7) and (b > 250):
    hard_ph.append(3)
  elif (a > 7) and (b < 250):
    hard_ph.append(4)
  else:
    hard_ph.append(5)

# %%
#all_data['hard_ph'] = hard_ph

# %%
sol_ha = []
for a,b in zip(all_data['Solids'], all_data['Hardness']):
  if (a > 25555) and (b >250):
    sol_ha.append(1)
  elif (a < 25555) and (b < 250):
    sol_ha.append(2)
  elif (a < 25555) and (b > 25555):
    sol_ha.append(3)
  elif (a > 25555) and (b < 25555):
    sol_ha.append(4)
  else:
    sol_ha.append(5)

# %%
all_data.columns
# Out:
# Index(['region_area_', 'ph', 'Hardness', 'Solids', 'Chloramines', 'Sulfate',
#        'Conductivity', 'Organic_carbon', 'Trihalomethanes', 'Turbidity',
#        'Potability', 'Sulph', 'ocph', 'ph_range', 'H30+', 'chl_ph'],
#       dtype='object')

# %%
all_data.describe()
# Out:
#                 ph     Hardness        Solids  Chloramines      Sulfate  \
# count  3276.000000  3276.000000   3276.000000  3276.000000  3276.000000
# mean     -8.818372   247.143387  22014.397337     6.817466   231.169298
# std      37.900017    32.879761   8768.570828     1.583085   188.255758
# min     -99.000000    98.205891    321.247422     0.047189   -99.000000
# 25%       5.283146   227.624429  15666.995108     5.822610   241.467961
# 50%       6.735249   247.741518  20928.138417     6.825488   319.405495
# 75%       7.870050   267.441347  27333.066938     7.810076   351.130869
# max      14.000000   373.897891  61227.500818    12.822189   481.775755
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity  \
# count   3276.000000     3276.000000      3276.000000  3276.000000
# mean     436.310111       14.389970        58.326669     3.966786
# std       80.824064        3.308162        39.201301     0.780382
# min      191.588754        2.305000       -99.000000     1.450000
# 25%      375.839414       12.170801        53.908688     3.439711
# 50%      431.989968       14.323338        65.560962     3.955028
# 75%      491.897304       16.662652        76.781609     4.500320
# max      763.447620       28.405000       124.115000     6.739000
#
#         Potability        Sulph         ocph     ph_range          H30+  \
# count  2260.000000  3276.000000  3276.000000  3276.000000  3.276000e+03
# mean      0.388496    -2.282459          inf   -11.948718 -1.483732e+01
# std       0.487516    76.140000          NaN    36.564745  3.534387e+01
# min       0.000000   -99.000000   -99.000000   -99.000000 -9.900000e+01
# 25%       0.000000   -99.000000     1.388723     3.000000  1.189836e-09
# 50%       0.000000    39.602377     1.894711     3.000000  4.118001e-08
# 75%       1.000000    50.679302     2.410879     4.000000  5.276274e-07
# max       1.000000  1250.286079          inf     6.000000  1.000000e+00
#
#             chl_ph
# count  3276.000000
# mean      2.131258
# std       1.060543
# min       1.000000
# 25%       1.000000
# 50%       2.000000
# 75%       3.000000
# max       4.000000

# %%
all_data['T/C'] = all_data['Trihalomethanes']/all_data['Chloramines']
all_data['Solids_tu'] = all_data['Solids']/all_data['Turbidity']
all_data['Solids_ha'] = all_data['Solids']/all_data['Hardness']
all_data['Solids_co'] = all_data['Solids']/all_data['Conductivity']

# %%
colormap = plt.cm.RdBu
plt.figure(figsize=(14,12))
plt.title('Pearson Correlation of Features', y=1.05, size=15)
sns.heatmap(build_data.corr(),linewidths=0.1,vmax=1.0, 
            square=True, cmap=colormap, linecolor='white', annot=True)

# %%
corrmat = all_data.corr()
f, ax = plt.subplots(figsize=(12, 9))

sns.heatmap(corrmat, vmax=.8, square=True);

# %%
# Top 10 Heatmap
k = 12 #number of variables for heatmap
cols = corrmat.nlargest(k, 'Potability')['Potability'].index
cm = np.corrcoef(all_data[cols].values.T)
sns.set(font_scale=1.25)
plt.figure(figsize=(12, 9))
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, yticklabels=cols.values, xticklabels=cols.values)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/lib/function_base.py:2536: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]

# %%
all_data.head()
# Out:
#        region_area_         ph    Hardness        Solids  Chloramines  \
# 0     region_area_1   3.716080  180.196811  18630.362669     6.330435
# 1   region_area_100   4.270716  217.611599  24405.555346     7.086700
# 2  region_area_1000   6.648849  232.462013  30733.808648     5.656462
# 3  region_area_1001 -99.000000  261.753637  21174.713291     7.314074
# 4  region_area_1002   9.323584  263.484560  15751.480111     5.196259
#
#       Sulfate  Conductivity  Organic_carbon  Trihalomethanes  Turbidity  \
# 0  -99.000000    602.990359       15.285013        56.444076   4.500656
# 1  297.951852    359.623910       13.583526        54.589840   3.763906
# 2  344.670335    267.809179       17.863444        35.411181   4.827527
# 3  -99.000000    582.848407       15.215849        90.367455   4.217553
# 4  297.593625    409.878704       10.727265        74.669285   3.006650
#
#    Potability      Sulph       ocph  ph_range          H30+  chl_ph  \
# 0         0.0 -99.000000   4.113209         2  1.922737e-04       2
# 1         0.0  69.766250   3.180620         2  5.361469e-05       1
# 2         0.0  51.839097   2.686697         3  2.244661e-07       2
# 3         0.0 -99.000000 -99.000000       -99 -9.900000e+01       1
# 4         0.0  31.918373   1.150552         5  4.746966e-10       4
#
#          T/C    Solids_tu   Solids_ha   Solids_co
# 0   8.916303  4139.476896  103.388970   30.896618
# 1   7.703140  6484.103475  112.151905   67.864106
# 2   6.260306  6366.366488  132.210026  114.760102
# 3  12.355283  5020.615365   80.895584   36.329709
# 4  14.369815  5238.880132   59.781416   38.429613

# %%
#Get the new dataset
train_n = all_data[:ntrain].copy()
test_n = all_data[ntrain:].copy()

# %%
X= train_n.drop(columns=['Potability', 'region_area_'])
y= train_n.Potability
test_n.drop(columns=['Potability', 'region_area_'], axis=1, inplace=True)

# %%
pip install lightgbm --quiet

# %%
pip install catboost --quiet
# Out:
#      |████████████████████████████████| 76.6 MB 75 kB/s

# %%
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from sklearn.model_selection import StratifiedKFold, KFold, train_test_split
from sklearn.metrics import f1_score

# %%
from collections import Counter
counter = Counter(y)
# estimate scale_pos_weight value
estimate = counter[0] / counter[1]
print('Estimate: %.3f' % estimate)
# Out:
# Estimate: 1.574

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import roc_auc_score

target = 'Potability'
features = [c for c in train_n.columns if c not in ['Potability', 'region_area_']]

# %% [markdown]
# # Xgboost

# %%
scores = 0
test_oofs = []
k = 10
kf = StratifiedKFold(n_splits=k, shuffle=True, random_state=22)

for i, (tr_idx, vr_idx) in enumerate(kf.split(train_n, train_n[target])):
    xtrain, ytrain = train_n.loc[tr_idx, features], train_n.loc[tr_idx, target]
    xval, yval = train_n.loc[vr_idx, features], train_n.loc[vr_idx, target]

    test = test_n[features]

   # training and validation
    model=XGBClassifier(scale_pos_weight=2, max_depth=5, 
                        learning_rate=0.11243242, n_estimators=1800, 
                        silent=True, metrics='auc')
    
    model.fit(xtrain, ytrain, eval_set=[(xval,yval)], early_stopping_rounds=100,verbose=100)
    pred = model.predict(xval)

    #predicting on test set
    predictions = model.predict_proba(test)[:,1]
    score = f1_score(yval, pred)
    #
    scores += score/k
    test_oofs.append(predictions)

    print('Fold {} : {}'.format(i, score))

print()
print()
print('f1_score : ', scores)
# Out:
# [0]	validation_0-error:0.442478
# Will train until validation_0-error hasn't improved in 100 rounds.
# [100]	validation_0-error:0.442478
# Stopping. Best iteration:
# [29]	validation_0-error:0.393805
#
# Fold 0 : 0.5821596244131455
# [0]	validation_0-error:0.433628
# Will train until validation_0-error hasn't improved in 100 rounds.
# [100]	validation_0-error:0.482301
# Stopping. Best iteration:
# [1]	validation_0-error:0.402655
#
# Fold 1 : 0.5333333333333333
# [0]	validation_0-error:0.376106
# Will train until validation_0-error hasn't improved in 100 rounds.
# [100]	validation_0-error:0.486726
# Stopping. Best iteration:
# [0]	validation_0-error:0.376106
#
# Fold 2 : 0.5971563981042655
# [0]	validation_0-error:0.477876
# Will train until validation_0-error hasn't improved in 100 rounds.
# [100]	validation_0-error:0.438053
# [200]	validation_0-error:0.39823
# [300]	validation_0-error:0.393805
# [400]	validation_0-error:0.376106
# [500]	validation_0-error:0.367257
# Stopping. Best iteration:
# [472]	validation_0-error:0.358407
#
# Fold 3 : 0.4774193548387097
# [0]	validation_0-error:0.380531
# Will train until validation_0-error hasn't improved in 100 rounds.
# [100]	validation_0-error:0.380531
# Stopping. Best iteration:
# [2]	validation_0-error:0.371681
#
# Fold 4 : 0.6216216216216217
# [0]	validation_0-error:0.49115
# Will train until validation_0-error hasn't improved in 100 rounds.
# [100]	validation_0-error:0.446903
# [200]	validation_0-error:0.415929
# [300]	validation_0-error:0.411504
# [400]	validation_0-error:0.367257
# Stopping. Best iteration:
# [391]	validation_0-error:0.362832
#
# Fold 5 : 0.5176470588235295
# [0]	validation_0-error:0.39823
# Will train until validation_0-error hasn't improved in 100 rounds.
# [100]	validation_0-error:0.429204
# Stopping. Best iteration:
# [0]	validation_0-error:0.39823
#
# Fold 6 : 0.5054945054945055
# [0]	validation_0-error:0.50885
# Will train until validation_0-error hasn't improved in 100 rounds.
# [100]	validation_0-error:0.415929
# Stopping. Best iteration:
# [83]	validation_0-error:0.393805
#
# Fold 7 : 0.5741626794258373
# [0]	validation_0-error:0.473451
# Will train until validation_0-error hasn't improved in 100 rounds.
# [100]	validation_0-error:0.371681
# Stopping. Best iteration:
# [85]	validation_0-error:0.340708
#
# Fold 8 : 0.6206896551724138
# [0]	validation_0-error:0.389381
# Will train until validation_0-error hasn't improved in 100 rounds.
# [100]	validation_0-error:0.39823
# Stopping. Best iteration:
# [0]	validation_0-error:0.389381
#
# Fold 9 : 0.5809523809523809
#
#
# f1_score :  0.5610636612179742

# %%
preds = np.mean(test_oofs, axis=0)
sub = [1 if i > 0.425 else 0 for i in preds]
ss['Potability'] = sub

# %%
ss['Potability'].value_counts()
# Out:
# 1    703
# 0    313
# Name: Potability, dtype: int64

# %%
ss.to_csv('scf.csv',index=False) # 0.6036

# %% [markdown]
# # Catboost

# %%
scores = 0
test_oofs = []
k = 5
kf = StratifiedKFold(n_splits=k, shuffle=True, random_state=22)

for i, (tr_idx, vr_idx) in enumerate(kf.split(train_n, train_n[target])):
    xtrain, ytrain = train_n.loc[tr_idx, features], train_n.loc[tr_idx, target]
    xval, yval = train_n.loc[vr_idx, features], train_n.loc[vr_idx, target]

    test = test_n[features]

   # training and validation
    model = CatBoostClassifier(scale_pos_weight=2, n_estimators=5000,eval_metric='AUC',max_depth=5,
                         learning_rate=0.112636787)
    
    model.fit(xtrain, ytrain, eval_set=[(xval,yval)], early_stopping_rounds=600,verbose=100)
    pred = model.predict(xval)

    #predicting on test set
    predictions = model.predict_proba(test)[:,1]
    score = f1_score(yval, pred)
    #
    scores += score/k
    test_oofs.append(predictions)

    print('Fold {} : {}'.format(i, score))

print()
print()
print('f1_score : ', scores)
# Out:
# 0:	test: 0.5297163	best: 0.5297163 (0)	total: 50.8ms	remaining: 4m 14s
# 100:	test: 0.6199278	best: 0.6441052 (8)	total: 382ms	remaining: 18.5s
# 200:	test: 0.6163796	best: 0.6441052 (8)	total: 714ms	remaining: 17.1s
# 300:	test: 0.6128520	best: 0.6441052 (8)	total: 1.07s	remaining: 16.7s
# 400:	test: 0.6080248	best: 0.6441052 (8)	total: 1.41s	remaining: 16.2s
# 500:	test: 0.6090150	best: 0.6441052 (8)	total: 1.75s	remaining: 15.8s
# 600:	test: 0.6107684	best: 0.6441052 (8)	total: 2.11s	remaining: 15.4s
# Stopped by overfitting detector  (600 iterations wait)
#
# bestTest = 0.6441052089
# bestIteration = 8
#
# Shrink model to first 9 iterations.
# Fold 0 : 0.5873320537428024
# 0:	test: 0.5575761	best: 0.5575761 (0)	total: 4.49ms	remaining: 22.5s
# 100:	test: 0.6304487	best: 0.6523156 (41)	total: 357ms	remaining: 17.3s
# 200:	test: 0.6238886	best: 0.6523156 (41)	total: 703ms	remaining: 16.8s
# 300:	test: 0.6196390	best: 0.6523156 (41)	total: 1.05s	remaining: 16.4s
# 400:	test: 0.6172460	best: 0.6523156 (41)	total: 1.39s	remaining: 15.9s
# 500:	test: 0.6066426	best: 0.6523156 (41)	total: 1.75s	remaining: 15.7s
# 600:	test: 0.6095719	best: 0.6523156 (41)	total: 2.1s	remaining: 15.4s
# Stopped by overfitting detector  (600 iterations wait)
#
# bestTest = 0.6523156266
# bestIteration = 41
#
# Shrink model to first 42 iterations.
# Fold 1 : 0.5536480686695279
# 0:	test: 0.5254550	best: 0.5254550 (0)	total: 6.57ms	remaining: 32.8s
# 100:	test: 0.6524209	best: 0.6650815 (51)	total: 392ms	remaining: 19s
# 200:	test: 0.6480155	best: 0.6650815 (51)	total: 725ms	remaining: 17.3s
# 300:	test: 0.6559618	best: 0.6650815 (51)	total: 1.07s	remaining: 16.7s
# 400:	test: 0.6511034	best: 0.6650815 (51)	total: 1.43s	remaining: 16.4s
# 500:	test: 0.6546854	best: 0.6650815 (51)	total: 1.77s	remaining: 15.9s
# 600:	test: 0.6552824	best: 0.6650815 (51)	total: 2.12s	remaining: 15.5s
# Stopped by overfitting detector  (600 iterations wait)
#
# bestTest = 0.6650815217
# bestIteration = 51
#
# Shrink model to first 52 iterations.
# Fold 2 : 0.5652173913043479
# 0:	test: 0.5067523	best: 0.5067523 (0)	total: 3.52ms	remaining: 17.6s
# 100:	test: 0.6843297	best: 0.6894145 (90)	total: 344ms	remaining: 16.7s
# 200:	test: 0.6740571	best: 0.6900527 (105)	total: 694ms	remaining: 16.6s
# 300:	test: 0.6687047	best: 0.6900527 (105)	total: 1.05s	remaining: 16.3s
# 400:	test: 0.6703516	best: 0.6900527 (105)	total: 1.39s	remaining: 15.9s
# 500:	test: 0.6743659	best: 0.6900527 (105)	total: 1.73s	remaining: 15.6s
# 600:	test: 0.6766098	best: 0.6900527 (105)	total: 2.08s	remaining: 15.2s
# 700:	test: 0.6827652	best: 0.6900527 (105)	total: 2.43s	remaining: 14.9s
# Stopped by overfitting detector  (600 iterations wait)
#
# bestTest = 0.6900527009
# bestIteration = 105
#
# Shrink model to first 106 iterations.
# Fold 3 : 0.5846867749419954
# 0:	test: 0.5437356	best: 0.5437356 (0)	total: 3.55ms	remaining: 17.7s
# 100:	test: 0.6908350	best: 0.6908350 (97)	total: 348ms	remaining: 16.9s
# 200:	test: 0.6657609	best: 0.6926877 (101)	total: 704ms	remaining: 16.8s
# 300:	test: 0.6509181	best: 0.6926877 (101)	total: 1.04s	remaining: 16.3s
# 400:	test: 0.6476861	best: 0.6926877 (101)	total: 1.38s	remaining: 15.9s
# 500:	test: 0.6389781	best: 0.6926877 (101)	total: 1.72s	remaining: 15.5s
# 600:	test: 0.6369195	best: 0.6926877 (101)	total: 2.07s	remaining: 15.2s
# 700:	test: 0.6373930	best: 0.6926877 (101)	total: 2.42s	remaining: 14.9s
# Stopped by overfitting detector  (600 iterations wait)
#
# bestTest = 0.692687747
# bestIteration = 101
#
# Shrink model to first 102 iterations.
# Fold 4 : 0.5893719806763283
#
#
# f1_score :  0.5760512538670004

# %%
preds = np.mean(test_oofs, axis=0)
sub = [1 if i > 0.47 else 0 for i in preds]
ss['Potability'] = sub

# %%
ss['Potability'].value_counts()
# Out:
# 1    708
# 0    308
# Name: Potability, dtype: int64

# %%
ss.to_csv('scf2.csv',index=False) # 0.6018
